# %%
import os 
import requests
import PyPDF2

# %%
lis = os.listdir('/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接')
lis = ['/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/'+i for i in lis]
lis
# Out:
# ['/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/514_深圳市齐普光电子股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/223_华体体育发展股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/298_广东瑞普科技股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/137_江苏腾旋科技股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/11_福建华博教育科技股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/487_无锡三立轴承股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/105_广州市德晟光电科技股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/569_江苏莱克科技有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/97_江西盛富莱光学科技股份有限公司.txt',
#  '/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/pdf链接/50_广州银狐科技股份有限公司.txt',
# ...

# %%
# 功能四
def pdf2txt(pdf_file):
    with open(pdf_file[:-4]+'.txt','w') as f:
        # print(pdf_file[:-4]+'.txt')
        # 创建一个PDF Reader对象
        pdf_reader = PyPDF2.PdfFileReader(pdf_file)
        # 遍历每页并提取文本
        for page_num in range(pdf_reader.numPages):
            page = pdf_reader.getPage(page_num)
            f.write(page.extractText())

# %%
for i in lis:
    with open(i,'r') as f:
        pdf_list = f.readlines()
    pdf_list = [i.strip().split(' ') for  i in pdf_list]
    for x in pdf_list:
        print(x)
        with open('/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/年报txt/'+x[0]+'.pdf','wb') as f:
            f.write(requests.get(x[1]).content)
        pdf2txt('/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/年报txt/'+x[0]+'.pdf')
# Out:
# ['2022年年度报告', 'http://static.cninfo.com.cn/finalpage/2023-04-20/1216504450.PDF']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 with open('/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/年报txt/'+x[0]+'.pdf','wb') as f:
#       8     f.write(requests.get(x[1]).content)
# ----> 9 pdf2txt('/Users/nanapower/学习资料/python_learnning/模块与项目/AI/图灵AI/巨潮资讯/年报爬取/年报txt/'+x[0]+'.pdf')
#
# Cell In[5], line 10, in pdf2txt(pdf_file)
#       8 for page_num in range(pdf_reader.numPages):
#       9     page = pdf_reader.getPage(page_num)
# ---> 10     f.write(page.extractText())
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/PyPDF2/_page.py:1870, in PageObject.extractText(self, Tj_sep, TJ_sep)
#    1864 """
#    1865 .. deprecated:: 1.28.0
#    1866
#    1867     Use :meth:`extract_text` instead.
#    1868 """
# ...
